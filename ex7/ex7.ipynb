# %%
def f(padded_input_size):
    cur_size = padded_input_size
    for i in range(4):
        #print(i)
        #print(cur_size - 4)
        cur_size = (cur_size - 4) / 2
        #print(cur_size)

    cur_size -= 4
    bottleneck_size = cur_size
    #print("bottleneck size", cur_size)

    for _ in range(4):
        cur_size = cur_size * 2 - 4

    return cur_size, bottleneck_size


padded_input_size = 380
f(380 + 184)
[(f(360 + p), p) for p in range(360)]
# Out:
# [((176.0, 14.75), 0),
#  ((177.0, 14.8125), 1),
#  ((178.0, 14.875), 2),
#  ((179.0, 14.9375), 3),
#  ((180.0, 15.0), 4),
#  ((181.0, 15.0625), 5),
#  ((182.0, 15.125), 6),
#  ((183.0, 15.1875), 7),
#  ((184.0, 15.25), 8),
#  ((185.0, 15.3125), 9),
#  ((186.0, 15.375), 10),
#  ((187.0, 15.4375), 11),
#  ((188.0, 15.5), 12),
#  ((189.0, 15.5625), 13),
#  ((190.0, 15.625), 14),
#  ((191.0, 15.6875), 15),
#  ((192.0, 15.75), 16),
#  ((193.0, 15.8125), 17),
#  ((194.0, 15.875), 18),
#  ((195.0, 15.9375), 19),
#  ((196.0, 16.0), 20),
#  ((197.0, 16.0625), 21),
#  ((198.0, 16.125), 22),
#  ((199.0, 16.1875), 23),
#  ((200.0, 16.25), 24),
#  ((201.0, 16.3125), 25),
#  ((202.0, 16.375), 26),
#  ((203.0, 16.4375), 27),
#  ((204.0, 16.5), 28),
#  ((205.0, 16.5625), 29),
#  ((206.0, 16.625), 30),
#  ((207.0, 16.6875), 31),
#  ((208.0, 16.75), 32),
#  ((209.0, 16.8125), 33),
#  ((210.0, 16.875), 34),
#  ((211.0, 16.9375), 35),
#  ((212.0, 17.0), 36),
#  ((213.0, 17.0625), 37),
# ...
